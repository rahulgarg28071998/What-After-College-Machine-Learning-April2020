# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.arange(4)

# %%
print(x)
# Out:
# [0 1 2 3]

# %%
plt.plot(x,color = "blue")
plt.plot(x**2 , color = "green")
plt.plot(x**3)
plt.xlabel("x axsis")
plt.ylabel("y axsis")
plt.title("x vs y graph")
plt.show()

# %%
plt.scatter(x ,  x**3  ,marker="*")

# %%
plt.scatter?

# %%
numbers = np.random.randint(0,10 ,7)
numbers2 = np.random.randint(0,10 ,7)
indices = np.arange(7)

# %%
print(numbers  )
print(indices)
# Out:
# [8 9 1 4 5 5 9]
# [0 1 2 3 4 5 6]

# %%
plt.bar(indices , numbers ,0.25 , label = "number1")
plt.bar(indices +0.25, numbers2 , 0.25 , color = "red" , label = "numbert2")
plt.legend()
plt.show()

# %%
#pie chart

# %%
l = ["algebra" , "calculus" , "c" ,"c++"]
values = [90, 80, 54 , 60]

# %%
plt.pie(values , labels = l , radius =1  , shadow=True , explode= ( 0,1,0,0))
plt.show()

# %%
##histogram and normal diatribution

# %%
u  = 5#0
sigma = 0.4#1

vals = u + sigma*np.random.randn(200)
plt.hist(vals)
# Out:
# (array([ 8., 10., 17., 48., 31., 32., 29., 15.,  6.,  4.]),
#  array([4.00676276, 4.21814981, 4.42953686, 4.64092391, 4.85231096,
#         5.06369801, 5.27508506, 5.48647211, 5.69785916, 5.9092462 ,
#         6.12063325]),
#  <a list of 10 Patch objects>)

# %%
np.random.randn?
